# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from lab_utils_multiclass_TF import *

# %%
# make 4-class dataset for classification
classes = 4
m =200
centers = [[-5, 2], [-2, -2], [1, 2], [5, -2]]
std = 1.0
X_train, y_train = make_blobs(n_samples=m, centers=centers, cluster_std=std,random_state=30)

plt_mc(X_train,y_train,classes, centers, std=std)

# %%
print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
# Out:
# X_train shape: (200, 2)
# y_train shape: (200,)

# %%
#Model
tf.random.set_seed(1234)  # applied to achieve consistent results
model = Sequential(
    [
        Dense(2, activation = 'relu',   name = "L1"),
        Dense(4, activation = 'linear', name = "L2")
    ]
)


#Aşağıdaki ifadeler ağı derler ve eğitir
model.compile(
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    optimizer=tf.keras.optimizers.Adam(0.01),
)

model.fit(X_train, y_train, epochs=20)
# Out:
# Epoch 1/20
# 7/7 [==============================] - 0s 2ms/step - loss: 1.2812
# Epoch 2/20
# 7/7 [==============================] - 0s 2ms/step - loss: 1.0799
# Epoch 3/20
# 7/7 [==============================] - 0s 2ms/step - loss: 0.9338
# Epoch 4/20
# 7/7 [==============================] - 0s 2ms/step - loss: 0.8264
# Epoch 5/20
# 7/7 [==============================] - 0s 2ms/step - loss: 0.7426
# Epoch 6/20
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6727
# Epoch 7/20
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6091
# Epoch 8/20
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5584
# Epoch 9/20
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5125
# Epoch 10/20
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4723
# Epoch 11/20
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4374
# Epoch 12/20
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4056
# Epoch 13/20
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3783
# Epoch 14/20
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3530
# Epoch 15/20
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3305
# Epoch 16/20
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3121
# Epoch 17/20
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2953
# Epoch 18/20
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2777
# Epoch 19/20
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2623
# Epoch 20/20
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2490

# %%
plt_cat_mc(X_train, y_train, model, classes)
# Out:
# 197/197 [==============================] - 0s 977us/step
